# %%
#install.packages("dplyr")
#install.packages("tidyr")
#install.packages("readr")
library(readr)
library(tidyr)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
data <- read_csv("data/2M4AB301.csv",skip=2)
# Out:
# Rows: 247 Columns: 132
#
# ── Column specification ──────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (132): Geolocation, Commodity Description, 2012 Jan, 2012 Feb, 2012 Mar,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
data %>% pivot_longer(!`Geolocation`,names_to="year_month",values_to="cpi")
# Out:
#       Geolocation
# 1     PHILIPPINES
# 2     PHILIPPINES
# 3     PHILIPPINES
# 4     PHILIPPINES
# 5     PHILIPPINES
# 6     PHILIPPINES
# 7     PHILIPPINES
# 8     PHILIPPINES
# 9     PHILIPPINES
# 10    PHILIPPINES
# 11    PHILIPPINES
# 12    PHILIPPINES
# 13    PHILIPPINES
# 14    PHILIPPINES
# 15    PHILIPPINES
# 16    PHILIPPINES
# 17    PHILIPPINES
# 18    PHILIPPINES
# 19    PHILIPPINES
# 20    PHILIPPINES
# 21    PHILIPPINES
# 22    PHILIPPINES
# 23    PHILIPPINES
# 24    PHILIPPINES
# 25    PHILIPPINES
# 26    PHILIPPINES
# 27    PHILIPPINES
# 28    PHILIPPINES
# 29    PHILIPPINES
# 30    PHILIPPINES
# ⋮     ⋮
# 32328 ..BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANAO (BARMM)
# 32329 ..BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANAO (BARMM)
# 32330 ..BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANAO (BARMM)
# 32331 ..BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANAO (BARMM)
# 32332 ..BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANAO (BARMM)
# ...
